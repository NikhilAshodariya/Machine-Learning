# %% [markdown]
# # Breast Cancer Dataset

# %% [markdown]
# 1. Number of Instances: 699 (as of 15 July 1992)
#
# 2. Number of Attributes: 10 plus the class attribute
#
# 3. Attribute Information: (class attribute has been moved to last column)
#
#    #  Attribute                     Domain
#    -- -----------------------------------------
#    1. Sample code number            id number
#    2. Clump Thickness               1 - 10
#    3. Uniformity of Cell Size       1 - 10
#    4. Uniformity of Cell Shape      1 - 10
#    5. Marginal Adhesion             1 - 10
#    6. Single Epithelial Cell Size   1 - 10
#    7. Bare Nuclei                   1 - 10
#    8. Bland Chromatin               1 - 10
#    9. Normal Nucleoli               1 - 10
#   10. Mitoses                       1 - 10
#   11. Class:                        (2 for benign, 4 for malignant)
#
# 4. Missing attribute values: 16
#
#    There are 16 instances in Groups 1 to 6 that contain a single missing
#    (i.e., unavailable) attribute value, now denoted by "?".
#
# 5. Class distribution:
#
#    Benign: 458 (65.5%)
#    Malignant: 241 (34.5%)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
dataFrame=pd.read_csv('Data/cancerdata.csv')

# %%
dataFrame.sample()
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 288                6                        1                         3
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 288                  1                            4            5
#
#      Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 288                5               10        1      4

# %%
dataFrame.drop('Class',axis=1,inplace=True)

# %%
dataFrame.sample()
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 491                5                        8                         9
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 491                  4                            3           10
#
#      Bland Chromatin  Normal Nucleoli  Mitoses
# 491                7                1        1

# %%
colors = ["g.","r.","c.","y.","k.",'-c.','r.','g.']

# %%
X=dataFrame[:]

# %% [markdown]
# ### Using PCA

# %%
X = PCA(n_components=2).fit_transform(X)

# %%
def toList(df):
    idx =df.index.tolist()
    columns=df.columns
    l=[]
    for i in idx:
        temp=[]
        for j in columns:
            a=df.get_value(i,j)
            temp.append(a)
        l.append(temp)
    return l

# %%
X=pd.DataFrame(X)

# %%
lis=toList(X)

# %%
kmeans2 = KMeans(n_clusters=2)
kmeans2.fit(lis)

centroids = kmeans2.cluster_centers_
labels = kmeans2.labels_

for i in range(len(lis)):
#     print("coordinate:",lis[i], "label:", labels[i])
    plt.plot(lis[i][0], lis[i][1], colors[labels[i]], markersize = 10)
# plt.show()

plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()

# %%
centroids
# Out:
# array([[ 9.2010939 , -0.33931403],
#        [-4.57060847,  0.16855296]])

# %%
kmeans3 = KMeans(n_clusters=3)
kmeans3.fit(lis)

centroids = kmeans3.cluster_centers_
labels = kmeans3.labels_

# print(centroids)
# print(labels)

for i in range(len(lis)):
#     print("coordinate:",lis[i], "label:", labels[i])
    plt.plot(lis[i][0], lis[i][1], colors[labels[i]], markersize = 10)
# plt.show()

plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()

# %%
centroids
# Out:
# array([[ 11.66978286,   2.02458145],
#        [ -4.66816332,   0.16701514],
#        [  6.24480329,  -2.70726551]])

# %%
kmeans4 = KMeans(n_clusters=4)
kmeans4.fit(lis)

centroids = kmeans4.cluster_centers_
labels = kmeans4.labels_

# print(centroids)
# print(labels)

for i in range(len(lis)):
#     print("coordinate:",lis[i], "label:", labels[i])
    plt.plot(lis[i][0], lis[i][1], colors[labels[i]], markersize = 10)
# plt.show()

plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()

# %%
centroids
# Out:
# array([[  6.24956312,   3.88282005],
#        [ -4.76098619,   0.11497391],
#        [  6.53591741,  -3.64147   ],
#        [ 13.02730778,   0.45073128]])
